# %% [markdown]
# # Cifar10 preparation. Convertion to binary classification.

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
data = pd.read_csv('https://www.openml.org/data/get_csv/16797613/cifar-10.arff')

# %%
data
# Out:
#         a0   a1   a2   a3   a4   a5   a6   a7   a8   a9  ...  a3063  a3064  \
# 0       26   17   13   13   13   14   14   15   14   10  ...    237    144
# 1       94  101   95   94   94   97  111  142  166  154  ...    145    147
# 2      183  158  166  167  169  171  163  163  160  161  ...    174    177
# 3      255  254  255  255  255  255  255  255  255  255  ...    255    255
# 4      182  156  156  144  118  132  148  118  136   85  ...     83     83
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...    ...    ...
# 59995   76   76   77   76   75   76   76   76   76   78  ...    185    177
# 59996   81   91   98  106  108  110   80   84   88   90  ...    107    143
# 59997   20   19   15   15   14   13   12   11   10    9  ...    112     68
# 59998   25   15   23   17   23   51   74   91  114  137  ...     84     83
# 59999   73   98   99   77   59  146  214  176  125  218  ...     89     88
#
#        a3065  a3066  a3067  a3068  a3069  a3070  a3071  class
# ...

# %%
c=9
class_ = data[data['class']==c]
class_['class'] = 1
other = data[data['class']!=c]

# %%
class_
# Out:
#         a0   a1   a2   a3   a4   a5   a6   a7   a8   a9  ...  a3063  a3064  \
# 4      182  156  156  144  118  132  148  118  136   85  ...     83     83
# 13     255  255  255  255  255  255  255  254  255  255  ...     24     32
# 24     164  171  159  142  168  221  214  205  216  222  ...      5      5
# 68     164  161  185  188  172  169  168  173  182  193  ...     51     44
# 69     214  197  219  213  180  203  233  232  233  230  ...     78     80
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...    ...    ...
# 59898   98   97   97   98   98   98   99   98   98   98  ...    236    235
# 59927  244  241  242  243  244  244  244  243  242  242  ...    184    184
# 59938  226  228  229  232  232  233  235  236  238  234  ...     75     80
# 59958   56   31   38   73  122  188  157  152  196  208  ...    170    170
# 59971  255  249  244  238  228  224  221  227  226  230  ...     45     52
#
#        a3065  a3066  a3067  a3068  a3069  a3070  a3071  class
# ...

# %%
cat = 0

for i in range(10):
    if(cat!=c and cat<10):
        index = other[other['class'] == cat].index[:5333]
        other.drop(index, inplace = True)    
    cat+=1

other['class'] = 0

other.drop(other.index[:3], inplace = True)

# %%
other
# Out:
#         a0   a1   a2   a3   a4   a5   a6   a7   a8   a9  ...  a3063  a3064  \
# 53189  168  169  165  166  167  170  175  183  186  187  ...    124    130
# 53193  217  213  212  210  210  208  207  208  210  211  ...     75     69
# 53205  138  134  132  129  129  127  125  123  124  126  ...    123    121
# 53206  205  202  203  203  203  203  198  201  203  203  ...    200    203
# 53226  149  155  161  168  171  171  171  169  169  170  ...    214    213
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...    ...    ...
# 59995   76   76   77   76   75   76   76   76   76   78  ...    185    177
# 59996   81   91   98  106  108  110   80   84   88   90  ...    107    143
# 59997   20   19   15   15   14   13   12   11   10    9  ...    112     68
# 59998   25   15   23   17   23   51   74   91  114  137  ...     84     83
# 59999   73   98   99   77   59  146  214  176  125  218  ...     89     88
#
#        a3065  a3066  a3067  a3068  a3069  a3070  a3071  class
# ...

# %%
new = pd.concat([class_, other], ignore_index=True)
new = new.sample(frac=1).reset_index(drop=True)
new
# Out:
#         a0   a1   a2   a3   a4   a5   a6   a7   a8   a9  ...  a3063  a3064  \
# 0       55  101  121  123  127  132  133  140  140  133  ...     73     67
# 1      255  254  255  255  255  255  255  255  255  255  ...     88     90
# 2       61   63   67   70   75   85   95   99  102  103  ...    110    105
# 3      140  141  143  149  149  151  157  156  155  152  ...    100    105
# 4      255  252  252  253  253  253  253  253  251  249  ...    254    253
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...    ...    ...
# 11995  164  171  159  142  168  221  214  205  216  222  ...      5      5
# 11996   84   93   98   93   88   94  103  101   98  104  ...     66     63
# 11997    9    8    8    8    7    7    7    7    7    8  ...    120    120
# 11998  131  128  126  179  131  165  179  173  165  140  ...    109    112
# 11999   79   49   57   81  105  102   66  112  120  101  ...     86     73
#
#        a3065  a3066  a3067  a3068  a3069  a3070  a3071  class
# ...

# %%
new.to_csv('cifar-10-binary.csv', index=False)
