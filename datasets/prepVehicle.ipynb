# %% [markdown]
# # Vehicle preparation

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
data = pd.read_csv('https://www.openml.org/data/get_csv/54/dataset_54_vehicle.arff')

# %%
data
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 1             91           41                    84           141
# 2            104           50                   106           209
# 3             93           41                    82           159
# 4             85           44                    70           205
# ..           ...          ...                   ...           ...
# 841           93           39                    87           183
# 842           89           46                    84           163
# 843          106           54                   101           222
# 844           86           36                    78           146
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# ...

# %%
c='saab'
target = 'Class'
target_vals = ['opel','saab','bus','van']

class_ = data[data[target]==c]
class_[target] = 'saab'

other = data[data[target]!=c]

# %%
other
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 1             91           41                    84           141
# 3             93           41                    82           159
# 4             85           44                    70           205
# 5            107           57                   106           172
# ..           ...          ...                   ...           ...
# 838           95           43                    76           142
# 839           90           44                    72           157
# 840           93           34                    66           140
# 842           89           46                    84           163
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# ...

# %%
class_
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 2            104           50                   106           209
# 9             93           44                    98           197
# 11            90           34                    66           136
# 18           104           54                   100           186
# 24            99           53                   105           219
# ..           ...          ...                   ...           ...
# 834           82           36                    51           114
# 837           94           46                    77           169
# 841           93           39                    87           183
# 843          106           54                   101           222
# 844           86           36                    78           146
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 2                      66                       10            207
# ...

# %%
cat = 0

for cat in target_vals:
    if(cat!=c):
        index = other[other[target] == cat].index[:137]
        other.drop(index, inplace = True)    


other[target] = 'other'

other.drop(other.index[:1], inplace = True)

# %%
other
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 495           94           45                    72           179
# 510           86           43                    70           126
# 528           95           47                    73           195
# 529           86           43                    61           119
# 531          107           55                   103           167
# ..           ...          ...                   ...           ...
# 838           95           43                    76           142
# 839           90           44                    72           157
# 840           93           34                    66           140
# 842           89           46                    84           163
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 495                    69                        6            156
# ...

# %%
new = pd.concat([class_, other], ignore_index=True)
new = new.sample(frac=1).reset_index(drop=True)
new
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0            104           52                   100           191
# 1             89           47                    83           169
# 2             97           38                    75           188
# 3            100           50                    98           204
# 4             86           40                    66           138
# ..           ...          ...                   ...           ...
# 429          100           51                   109           231
# 430           96           39                    64           111
# 431           92           45                    74           187
# 432           95           43                    76           142
# 433           88           35                    60           143
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      59                        9            197
# ...

# %%
new.to_csv('vehicle-binary.csv', index=False)
